# %% [markdown]
# # SPRINT 5

# %% [markdown]
# Nivel 1, ejercicio 1:
#
# ![image.png](attachment:image.png)
#
# Captura de el modelo de nuestra base de datos s401 transactions. Podemos ver la relacion entre tablas. hay una tabal sin relacion que acumla medidas. Cree una tabla nueva llamada highspending users para poder filtrar los usuarios que tenían una media de gasto mayor a 300 para el ejercicio 8.

# %% [markdown]
# ### VISTA DE INFORME POWER BI - NIVEL 1, ejercicios 2-9
#
# ![image.png](attachment:image.png)

# %% [markdown]
# NIVEL 1, ejercicio 2:
#
# El gráfico nos muestra las ventas totales por año. 2021 supera el kpi de 25.000 € con creces, sin embargo 2022 no llega, por poco. Hay que añadir que 2022 solo fue activo en ventas hasta marzo según nuestra base de datos, de ahí que el total sea menor. Cuando recibamos el resto de datos de 2022, es de esperar que se supere el kpi establecido.
#
#
# NIVEL 1, ejercicio 3 & 4:
#
# Codigo DAX: Media de ventas = AVERAGE('s401 transactions'[amount])
#
# Este gráfico nos muestra la media de ventas por año. Podemos observar como el año 2021 supera el kpi establecido (línea roja, 250), mientras que en 2022 no se llega a la media esperada. Si obtuviesemos datos del resto de meses, podríamos saber si se llega a superar el kpi, pero con la informacion que tenemos no se llegó al objetivo establecido en 2022.
#
# NIVEL 1, ejercicio 5:
#
# Código DAX: kpi empresas per country =
# DISTINCTCOUNT('s401 companies'[company_id])
#
# En este gráfico observamos cuantas empresas han realizado transacciones por país. El kpi es de 3 empresas por país, el cual se cumple para la mayoría de países, exceptuándo China y España. Incrementar los esfuerzos en marketing y publicidad de la marca en China y España podría aumentar el numero de transacciones y por ende los beneficios de la empresa. Cabe a destacar que el grueso de las empresas perteneces a paises de habal anglosajona o del marco económico europeo. Abrir mercado en Asia y Africa podría ser un buen movimiento de cara a expandir el rango de clientela.
#
# NIVEL 1, ejercicio 6:
#
# Aquí podemos observar la trayectoria que siguen las transacciones declinadas a lo largo de los meses. Abril, Agosto y Diciembre son los meses con mayor número de transacciones declinadas. Hay un tendencia de aumento a lo largo que transcurre el año, se llega al tope en los meses que preceeden al verano, para bajar de nuevo entrando el otoño. En Diciembre suben las transacciones declinadas debido a que hay un mayor numero de compras (Navidad), por tanto también de devoluciones.
#
# NIVEL 1, ejercicio 7:
#
# La gráfica sigue una tendencia muy similar a las declinadas del ejercicio 6, ya que ambas categorías de datos van de la mano. Enero y Noviembre son los únicos meses por debajo del kpi de 10.000€. Entrar dentro de la celebración del Black Friday podría aumentar las ventas en Noviembre. Enero es un mes que, respaldado por datos históricos sobre ventas a lo largo de los meses, es flojo debido a la cultura de consumo de las navidades.
#
# NIVEL 1, ejercicio 8:
#
# La tabla de la izquierda muestra info sobre usuarios, tanto gastos totales como gasto medio, además de la edad. Se peude observar como, a medida que aumentamos edad o gasto medio, hay una tendencia de aumento de la suma total de transacciones de ese usuario. La tabla de la derecha simplemente recopila información de los usuarios que tienen una media de gasto superior a 300.
#
# NIVEL 1, ejercicio 9:
# Este ejercicio son las descripciones que podemos encontrar en este documento.
